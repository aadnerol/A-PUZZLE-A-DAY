# %% [markdown]
# # Solutions to A-PUZZLE-A-DAY

# %%
from visualize import plot_solution, extract_date, save_solution
from solver import solve, generate_all_placements
from board import build_target_board

# %% [markdown]
# ## Enter date

# %%
month = "september"
day = 11

# %% [markdown]
# ## Solution

# %%
board = build_target_board(month=month, day=day)
placements = generate_all_placements(board=board)
solution = solve(board, placements)
plot_solution(solution=solution)

# %% [markdown]
# ## Save Solution

# %%
# save_solution(solution=solution)
